# %% [markdown]
# # Titanic Project -

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.isnull().sum() # Check null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe() # statistical info about the data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Handling Null Values & drop unwanted columns -

# %%
df = df.drop(columns='Cabin',axis=1)

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
print(df['Embarked'].mode())
# Out:
# 0    S
# dtype: object

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum() # Check the null values again
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Sex & Embark are categorical data so need to change it in numeric values -

# %%
df.replace({'Sex':{'male':0,'female':1}, 'Embarked':{'S':0,'C':1,'Q':2}}, inplace=True)

# %%
# Columns which are not of much importance in this process needs to be removed - Pessenger id, name, ticket, Survived

# %%
 df = df.drop(columns = ['PassengerId','Name','Ticket'],axis=1)

# %%
df.corr() # Correlation Matrix
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481  0.543351 -0.069809 -0.035322  0.081629
# Pclass   -0.338481  1.000000 -0.131900 -0.331339  0.083081  0.018443
# Sex       0.543351 -0.131900  1.000000 -0.084153  0.114631  0.245489
# Age      -0.069809 -0.331339 -0.084153  1.000000 -0.232625 -0.179191
# SibSp    -0.035322  0.083081  0.114631 -0.232625  1.000000  0.414838
# Parch     0.081629  0.018443  0.245489 -0.179191  0.414838  1.000000
# Fare      0.257307 -0.549500  0.182333  0.091566  0.159651  0.216225
# Embarked  0.106811  0.045702  0.116569  0.007461 -0.059961 -0.078665
#
#               Fare  Embarked
# Survived  0.257307  0.106811
# Pclass   -0.549500  0.045702
# Sex       0.182333  0.116569
# Age       0.091566  0.007461
# SibSp     0.159651 -0.059961
# Parch     0.216225 -0.078665
# Fare      1.000000  0.062142
# Embarked  0.062142  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,linewidth=.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
# Check Data Distribution -

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,fontsize=1,figsize=(30,20))
plt.show()

# %%
#plot histogram data vizualization
df.hist(bins=20,figsize=(10,10))
#plot showing
plt.show()

# %%
ax=sns.countplot(x='Survived',data=df)
print(df['Survived'].value_counts())
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
ax=sns.countplot(x='Pclass',data=df)
print(df['Pclass'].value_counts())
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
ax=sns.countplot(x='Sex',data=df)
print(df['Sex'].value_counts())
# Out:
# 0    577
# 1    314
# Name: Sex, dtype: int64

# %%
ax=sns.countplot(x='SibSp',data=df)
print(df['SibSp'].value_counts())
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
ax=sns.countplot(x='Parch',data=df)
print(df['Parch'].value_counts())
# Out:
# 0    678
# 1    118
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
ax=sns.countplot(x='Embarked',data=df)
print(df['Embarked'].value_counts())
# Out:
# 0    646
# 1    168
# 2     77
# Name: Embarked, dtype: int64

# %%
# Positively & Negatively correlated -
plt.figure(figsize=(22,7))
df.corr()['Survived'].sort_values(ascending=False).drop(['Survived']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Column With Target Names',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %%
# Split data dependent & independent variable in x & y -
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
x.skew()
# Out:
# Pclass     -0.630548
# Sex         0.618921
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# Embarked    1.543397
# dtype: float64

# %%
# Remove the Skweness of the data
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.skew().sort_values(ascending=False) # For descending
# Out:
# Parch       1.228795
# Embarked    1.013716
# SibSp       0.808608
# Sex         0.618921
# Age         0.064420
# Fare       -0.040329
# Pclass     -0.441438
# dtype: float64

# %%
# Outliers Check

# %%
x.dtypes
# Out:
# Pclass      float64
# Sex         float64
# Age         float64
# SibSp       float64
# Parch       float64
# Fare        float64
# Embarked    float64
# dtype: object

# %%
x.boxplot(figsize=[10,8])
plt.show()

# %%
x.shape
# Out:
# (891, 7)

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z.shape
# Out:
# (891, 7)

# %%
threshold=2.8
print(np.where(z>2.8))
# Out:
# (array([ 96, 116, 179, 258, 263, 271, 277, 302, 413, 466, 481, 493, 597,
#        630, 633, 672, 674, 679, 732, 737, 745, 806, 815, 822, 851],
#       dtype=int64), array([2, 2, 5, 5, 5, 5, 5, 5, 5, 5, 5, 2, 5, 2, 5, 2, 5, 5, 5, 5, 2, 5,
#        5, 5, 2], dtype=int64))

# %%
x_new=x[(z<2.8).all(axis=1)]
print(x.shape)
print(x_new.shape)
# Out:
# (891, 7)
# (866, 7)

# %%
# % data loss
loss_percent=(891-866)/891*100
print(loss_percent)
# Out:
# 2.8058361391694726

# %%
# Plot boxplot - To Check outliers 
x_new.boxplot(figsize=[10,8])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_new=sc.fit_transform(x_new)
x_new
# Out:
# array([[ 0.84878089, -0.75233212, -0.54058928, ..., -0.56732034,
#         -1.05519341, -0.617029  ],
#        [-1.48485283,  1.3292002 ,  0.7053195 , ..., -0.56732034,
#          1.46359407,  1.57380434],
#        [ 0.84878089,  1.3292002 , -0.21750484, ..., -0.56732034,
#         -0.95428691, -0.617029  ],
#        ...,
#        [ 0.84878089,  1.3292002 ,  0.07363861, ...,  1.82369446,
#          0.27238083, -0.617029  ],
#        [-1.48485283, -0.75233212, -0.21750484, ..., -0.56732034,
#          0.5441252 ,  1.57380434],
#        [ 0.84878089, -0.75233212,  0.25151384, ..., -0.56732034,
#         -0.97962248,  1.71509309]])

# %%
# Training process
# Finding best random state
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
maxAccu=0 # max accuracy
maxRS=0 # best random state value for which max accuracy is achieved
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train) # Fitting the data will train the model
    predrf=LR.predict(x_test) # Predicting the data # Predicted traget variable
    acc=accuracy_score(y_test,predrf) # two target varaible # accuracy score
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu,"on Randon_state ",maxRS)
# Out:
# Best accuracy is  0.8603351955307262 on Randon_state  11

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=11)

# %%
# Logistic Regression # Training
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(x_train,y_train)
predlr=LR.predict(x_test)
print("Accuracy",accuracy_score(y_test,predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# Accuracy 86.03351955307262
# [[107  11]
#  [ 14  47]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       118
#            1       0.81      0.77      0.79        61
#
#     accuracy                           0.86       179
#    macro avg       0.85      0.84      0.84       179
# weighted avg       0.86      0.86      0.86       179

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print("Accuracy",accuracy_score(y_test,preddt)*100)
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# Accuracy 81.00558659217877
# [[101  17]
#  [ 17  44]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       118
#            1       0.72      0.72      0.72        61
#
#     accuracy                           0.81       179
#    macro avg       0.79      0.79      0.79       179
# weighted avg       0.81      0.81      0.81       179

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print("Accuracy",accuracy_score(y_test,predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy 83.79888268156425
# [[106  12]
#  [ 17  44]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       118
#            1       0.79      0.72      0.75        61
#
#     accuracy                           0.84       179
#    macro avg       0.82      0.81      0.82       179
# weighted avg       0.84      0.84      0.84       179

# %%
# SVC - Support Vector Classifier
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
ad_pred=svc.predict(x_test)
print("Accuracy",accuracy_score(y_test,ad_pred)*100)
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# Accuracy 87.15083798882681
# [[115   3]
#  [ 20  41]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       118
#            1       0.93      0.67      0.78        61
#
#     accuracy                           0.87       179
#    macro avg       0.89      0.82      0.85       179
# weighted avg       0.88      0.87      0.87       179

# %%
# SVC is performing better then other models with 87% accuracy.

# %%
# Check Overfitting - Use Cross Validation Score
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(LR,x,y,cv=5)
print("Cross Validation Score Of Logistic Regression Model :",scr.mean())
scr2=cross_val_score(rf,x,y,cv=5)
print("Cross Validation Score Of Random Forest Model :",scr2.mean())
scr3=cross_val_score(svc,x,y,cv=5)
print("Cross Validation Score Of SVC Model :",scr3.mean())
# Out:
# Cross Validation Score Of Logistic Regression Model : 0.7923859142552256
# Cross Validation Score Of Random Forest Model : 0.8137279517921033
# Cross Validation Score Of SVC Model : 0.822666499278137

# %%
# Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
# Create parameters list to pass in GridSearchCV
parameters={'max_features':['auto','sqrt','log2'],'max_depth':[4,5,6,7,8],'criterion':['gini','entropy']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring="accuracy")
GCV.fit(x_train,y_train) # fitting the data in model
GCV.best_params_ # Printing the best parameter found by GridSearchCV
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt'}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test) # predicting with best parameters
accuracy_score(y_test,GCV_pred) # checking final accuracy
# Out:
# 0.8715083798882681

# %%
# ROC AUC Plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %%
# Final accuracy is 87% & AUC score is 90% - good.

# %%
# Conclusion:
Titanic=np.array(y_test)
predicted=np.array(LR.predict(x_test))
df_1=pd.DataFrame({'original':Titanic,'predicted':predicted},index=range(len(Titanic)))
df_1
# Out:
#      original  predicted
# 0           1          1
# 1           1          0
# 2           0          0
# 3           0          0
# 4           0          0
# 5           0          0
# 6           0          0
# 7           1          1
# 8           0          0
# 9           1          1
# 10          0          0
# 11          0          0
# 12          0          0
# 13          0          0
# 14          0          0
# 15          0          0
# 16          0          0
# 17          0          0
# 18          0          0
# 19          1          1
# 20          0          0
# 21          0          0
# 22          0          0
# 23          0          0
# 24          0          0
# 25          0          0
# 26          0          0
# 27          0          0
# 28          0          0
# 29          0          0
# 30          1          1
# 31          1          1
# 32          0          0
# 33          1          1
# 34          1          0
# 35          0          0
# ...

# %%
# Saving the model in pickle format

# %%
# Pickeling of file or serialization of a file
import joblib
joblib.dump(GCV.best_estimator_,"Titanic.pkl")
# Out:
# ['Titanic.pkl']

# %% [markdown]
# # Thank You...!!!
